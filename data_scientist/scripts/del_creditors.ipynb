# %%
import json

# %%
with open(r'C:\Users\Alex\Desktop\VSP_news_analysis\data_scientist\data\processed\dataset_v2.3.json','r',encoding='utf-8') as file:
    data = json.load(file)

# %%
for i in data:
    del i['role_impact']['creditors']

# %%
with open(r'C:\Users\Alex\Desktop\VSP_news_analysis\data_scientist\data\processed\dataset_v2.3.json','w',encoding='utf-8') as file:
    json.dump(data,file,ensure_ascii=False)
